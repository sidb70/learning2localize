# %%
import pyexr
import json
import numpy as np
import matplotlib.pyplot as plt
import cv2
import math
import open3d as o3d
import json
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def pc_img_to_pcd(pc_img, color_img=None):
    pc_3d = pc_img.reshape(-1,3)
    if color_img is None:
        colors_3d = np.zeros_like(pc_3d)
    else:
        colors_3d = color_img.reshape(-1,3)
    #remove nan points
    colors_3d = colors_3d[~np.isnan(pc_3d).any(axis=1)]
    pc_3d = pc_3d[~np.isnan(pc_3d).any(axis=1)]
    assert pc_3d.shape == colors_3d.shape

    pcd = o3d.geometry.PointCloud()
    pcd.points = o3d.utility.Vector3dVector(pc_3d)
    pcd.colors = o3d.utility.Vector3dVector(colors_3d / 255.0)
    return pcd

# %%
rgb_img = cv2.imread('/home/siddhartha/RIVAL/learning2localize/blender/dataset/raw/apple_orchard-5-20/0a70b02b-2921-4bdb-b3de-f9d537dfc79d_rgb0000.png')
rgb_img = cv2.cvtColor(rgb_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_img)
plt.axis('off') 
plt.show()

cv2.imwrite('/home/siddhartha/Downloads/rgb.png', cv2.cvtColor(rgb_img, cv2.COLOR_RGB2BGR)) 

pc_path = '/home/siddhartha/RIVAL/learning2localize/blender/dataset/raw/apple_orchard-5-20/0a70b02b-2921-4bdb-b3de-f9d537dfc79d_pc.npy'
pc_img = np.load(pc_path)

pcd= pc_img_to_pcd(pc_img, rgb_img)
o3d.visualization.draw_geometries([pcd])

# %%
import sys 
from blender import utils
exr_path = '/home/siddhartha/RIVAL/learning2localize/blender/dataset/raw/apple_orchard-5-20/0a70b02b-2921-4bdb-b3de-f9d537dfc79d_id0000.exr'
id_mapping_path = '/home/siddhartha/RIVAL/learning2localize/blender/dataset/raw/apple_orchard-5-20/0a70b02b-2921-4bdb-b3de-f9d537dfc79d_id_map.json'
visible_objs, object_ids,inst_mask, id_to_name = utils.get_visible_objects(exr_path, id_mapping_path)

visible_objs
# Out:
# [(1, 'apple1'),
#  (3, 'apple3'),
#  (5, 'apple5'),
#  (7, 'apple7'),
#  (14, 'apple14'),
#  (15, 'apple15'),
#  (18, 'apple18'),
#  (21, 'apple21'),
#  (22, 'apple22'),
#  (25, 'apple25'),
#  (29, 'apple29'),
#  (35, 'apple35'),
#  (36, 'apple36'),
#  (39, 'apple39'),
#  (41, 'apple41'),
#  (48, 'apple48'),
#  (54, 'apple54'),
#  (55, 'apple55'),
#  (70, 'apple70'),
#  (74, 'apple74'),
#  (78, 'apple78'),
#  (79, 'apple79'),
#  (89, 'apple89'),
#  (90, 'apple90'),
#  (97, 'apple97'),
#  (101, 'apple101'),
#  (102, 'apple102'),
#  (103, 'apple103'),
#  (119, 'apple119'),
#  (122, 'apple122'),
#  (125, 'apple125'),
#  (132, 'apple132'),
#  (136, 'apple136'),
#  (138, 'apple138'),
#  (152, 'apple152'),
#  (153, 'apple153'),
#  (158, 'apple158'),
#  (163, 'apple163'),
#  (164, 'apple164'),
#  (167, 'apple167'),
#  (171, 'apple171'),
#  (173, 'apple173'),
#  (178, 'apple178'),
#  (183, 'apple183'),
#  (187, 'apple187'),
#  (190, 'apple190'),
#  (194, 'apple194'),
#  (201, 'branches.000'),
#  (215, 'branches.014'),
#  (258, 'branches.057'),
#  (263, 'branches.062'),
#  (269, 'branches.068'),
#  (270, 'branches.069'),
#  (271, 'branches.070'),
#  (276, 'branches.075'),
#  (294, 'branches.093'),
#  (307, 'branches.106'),
#  (318, 'branches.117'),
#  (319, 'branches.118'),
#  (320, 'branches.119'),
#  (321, 'branches.120'),
#  (322, 'branches.121'),
#  (323, 'branches.122'),
#  (327, 'branches.126'),
#  (328, 'branches.127'),
#  (329, 'branches.128'),
#  (330, 'branches.129'),
#  (331, 'branches.130'),
#  (332, 'branches.131'),
#  (333, 'branches.132'),
#  (334, 'branches.133'),
#  (335, 'branches.134'),
#  (336, 'branches.135'),
#  (337, 'branches.136'),
#  (338, 'branches.137'),
#  (339, 'branches.138'),
#  (340, 'branches.139'),
#  (341, 'branches.140'),
#  (342, 'branches.141'),
#  (343, 'branches.142'),
#  (344, 'branches.143'),
#  (345, 'branches.144'),
#  (346, 'branches.145'),
#  (351, 'branches.150'),
#  (353, 'branches.152'),
#  (355, 'branches.154'),
#  (357, 'branches.156'),
#  (358, 'branches.157'),
#  (359, 'branches.158'),
#  (360, 'branches.159'),
#  (361, 'branches.160'),
#  (362, 'branches.161'),
#  (366, 'branches.165'),
#  (367, 'branches.166'),
#  (368, 'branches.167'),
#  (370, 'branches.169'),
#  (371, 'branches.170'),
#  (372, 'branches.171'),
#  (373, 'branches.172'),
#  (374, 'branches.173'),
#  (375, 'branches.174'),
#  (376, 'branches.175'),
#  (377, 'branches.176'),
#  (378, 'branches.177'),
#  (379, 'branches.178'),
#  (380, 'branches.179'),
#  (381, 'branches.180'),
#  (383, 'branches.182'),
#  (384, 'branches.183'),
#  (385, 'branches.184'),
#  (386, 'branches.185'),
#  (387, 'branches.186'),
#  (388, 'branches.187'),
#  (389, 'branches.188'),
#  (390, 'branches.189'),
#  (392, 'branches.191'),
#  (393, 'branches.192'),
#  (394, 'branches.193'),
#  (395, 'branches.194'),
#  (396, 'branches.195'),
#  (397, 'branches.196'),
#  (398, 'branches.197'),
#  (402, 'branches.201'),
#  (403, 'branches.202'),
#  (404, 'branches.203'),
#  (405, 'branches.204'),
#  (406, 'branches.205'),
#  (407, 'branches.206'),
#  (408, 'branches.207'),
#  (409, 'branches.208'),
#  (411, 'branches.210'),
#  (412, 'branches.211'),
#  (413, 'branches.212'),
#  (414, 'branches.213'),
#  (416, 'branches.215'),
#  (418, 'branches.217'),
#  (419, 'branches.218'),
#  (420, 'branches.219'),
#  (425, 'branches.224'),
#  (426, 'branches.225'),
#  (427, 'branches.226'),
#  (428, 'branches.227'),
#  (431, 'branches.230'),
#  (432, 'branches.231'),
#  (433, 'branches.232'),
#  (437, 'branches.236'),
#  (466, 'branches.265'),
#  (467, 'branches.266'),
#  (472, 'branches.271'),
#  (476, 'branches.275'),
#  (477, 'branches.276'),
#  (478, 'branches.277'),
#  (479, 'branches.278'),
#  (480, 'branches.279'),
#  (481, 'branches.280'),
#  (482, 'branches.281'),
#  (483, 'branches.282'),
#  (484, 'branches.283'),
#  (485, 'branches.284'),
#  (486, 'branches.285'),
#  (487, 'branches.286'),
#  (488, 'branches.287'),
#  (489, 'branches.288'),
#  (490, 'branches.289'),
#  (514, 'branches.313'),
#  (517, 'branches.316'),
#  (518, 'branches.317'),
#  (519, 'branches.318'),
#  (520, 'branches.319'),
#  (521, 'branches.320'),
#  (522, 'branches.321'),
#  (523, 'branches.322'),
#  (524, 'branches.323'),
#  (525, 'branches.324'),
#  (526, 'branches.325'),
#  (527, 'branches.326'),
#  (528, 'branches.327'),
#  (529, 'branches.328'),
#  (530, 'branches.329'),
#  (543, 'branches.342'),
#  (549, 'branches.348'),
#  (550, 'branches.349'),
#  (555, 'branches.354'),
#  (556, 'branches.355'),
#  (557, 'branches.356'),
#  (560, 'branches.359'),
#  (565, 'branches.364'),
#  (566, 'branches.365'),
#  (568, 'branches.367'),
#  (583, 'branches.382'),
#  (596, 'branches.395'),
#  (599, 'branches.398'),
#  (600, 'branches.399'),
#  (601, 'branches.400'),
#  (602, 'branches.401'),
#  (603, 'branches.402'),
#  (604, 'branches.403'),
#  (605, 'branches.404'),
#  (606, 'branches.405'),
#  (607, 'branches.406'),
#  (609, 'branches.408'),
#  (610, 'branches.409'),
#  (616, 'branches.415'),
#  (617, 'branches.416'),
#  (620, 'branches.419'),
#  (621, 'branches.420'),
#  (622, 'branches.421'),
#  (623, 'branches.422'),
#  (631, 'branches.430'),
#  (636, 'branches.435'),
#  (644, 'branches.443'),
#  (645, 'branches.444'),
#  (649, 'branches.448'),
#  (654, 'branches.453'),
#  (659, 'branches.458'),
#  (660, 'branches.459'),
#  (661, 'branches.460'),
#  (662, 'branches.461'),
#  (663, 'branches.462'),
#  (664, 'branches.463'),
#  (665, 'branches.464'),
#  (666, 'branches.465'),
#  (667, 'branches.466'),
#  (668, 'branches.467'),
#  (669, 'branches.468'),
#  (671, 'branches.470'),
#  (673, 'branches.472'),
#  (674, 'branches.473'),
#  (675, 'branches.474'),
#  (683, 'branches.482'),
#  (686, 'branches.485'),
#  (687, 'branches.486'),
#  (688, 'branches.487'),
#  (702, 'branches.501'),
#  (710, 'branches.509'),
#  (712, 'branches.511'),
#  (713, 'branches.512'),
#  (715, 'branches.514'),
#  (718, 'branches.517'),
#  (719, 'branches.518'),
#  (720, 'branches.519'),
#  (723, 'branches.522'),
#  (725, 'branches.524'),
#  (726, 'branches.525'),
#  (727, 'branches.526'),
#  (728, 'branches.527'),
#  (732, 'branches.531'),
#  (733, 'branches.532'),
#  (734, 'branches.533'),
#  (735, 'branches.534'),
#  (736, 'branches.535'),
#  (737, 'branches.536'),
#  (738, 'branches.537'),
#  (740, 'branches.539'),
#  (741, 'branches.540'),
#  (752, 'branches.551'),
#  (753, 'branches.552'),
#  (754, 'branches.553'),
#  (755, 'branches.554'),
#  (756, 'branches.555'),
#  (757, 'branches.556'),
#  (758, 'branches.557'),
#  (765, 'branches.564'),
#  (767, 'branches.566'),
#  (768, 'branches.567'),
#  (772, 'branches.571'),
#  (773, 'branches.572'),
#  (778, 'branches.577'),
#  (779, 'branches.578'),
#  (781, 'branches.580'),
#  (782, 'branches.581'),
#  (783, 'branches.582'),
#  (784, 'branches.583'),
#  (786, 'branches.585'),
#  (788, 'branches.587'),
#  (789, 'branches.588'),
#  (790, 'branches.589'),
#  (791, 'branches.590'),
#  (792, 'branches.591'),
#  (793, 'branches.592'),
#  (794, 'branches.593'),
#  (795, 'branches.594'),
#  (797, 'branches.596'),
#  (798, 'branches.597'),
#  (799, 'branches.598'),
#  (801, 'branches.600'),
#  (806, 'branches.605'),
#  (807, 'branches.606'),
#  (810, 'branches.609'),
#  (811, 'branches.610'),
#  (813, 'branches.612'),
#  (814, 'branches.613'),
#  (815, 'branches.614'),
#  (816, 'branches.615'),
#  (818, 'branches.617'),
#  (819, 'branches.618'),
#  (820, 'branches.619'),
#  (821, 'branches.620'),
#  (823, 'branches.622'),
#  (824, 'branches.623'),
#  (825, 'branches.624'),
#  (826, 'branches.625'),
#  (827, 'branches.626'),
#  (828, 'branches.627'),
#  (829, 'branches.628'),
#  (830, 'branches.629'),
#  (831, 'branches.630'),
#  (832, 'branches.631'),
#  (833, 'branches.632'),
#  (834, 'branches.633'),
#  (846, 'branches.645'),
#  (847, 'branches.646'),
#  (852, 'branches.651'),
#  (856, 'branches.655'),
#  (857, 'branches.656'),
#  (858, 'branches.657'),
#  (859, 'branches.658'),
#  (860, 'branches.659'),
#  (861, 'branches.660'),
#  (863, 'branches.662'),
#  (865, 'branches.664'),
#  (866, 'branches.665'),
#  (868, 'branches.667'),
#  (869, 'branches.668'),
#  (872, 'branches.671'),
#  (873, 'branches.672'),
#  (874, 'branches.673'),
#  (875, 'branches.674'),
#  (876, 'branches.675'),
#  (880, 'branches.679'),
#  (881, 'branches.680'),
#  (882, 'branches.681'),
#  (883, 'branches.682'),
#  (884, 'branches.683'),
#  (885, 'branches.684'),
#  (886, 'branches.685'),
#  (887, 'branches.686'),
#  (888, 'branches.687'),
#  (889, 'branches.688'),
#  (890, 'branches.689'),
#  (894, 'branches.693'),
#  (896, 'branches.695'),
#  (898, 'branches.697'),
#  (899, 'branches.698'),
#  (900, 'branches.699'),
#  (901, 'branches.700'),
#  (902, 'branches.701'),
#  (903, 'branches.702'),
#  (905, 'branches.704'),
#  (908, 'branches.707'),
#  (909, 'branches.708'),
#  (910, 'branches.709'),
#  (911, 'branches.710'),
#  (913, 'branches.712'),
#  (916, 'branches.715'),
#  (919, 'branches.718'),
#  (921, 'branches.720'),
#  (922, 'branches.721'),
#  (924, 'branches.723'),
#  (926, 'branches.725'),
#  (927, 'branches.726'),
#  (928, 'branches.727'),
#  (929, 'branches.728'),
#  (930, 'branches.729'),
#  (931, 'branches.730'),
#  (932, 'branches.731'),
#  (933, 'branches.732'),
#  (934, 'branches.733'),
#  (935, 'branches.734'),
#  (936, 'branches.735'),
#  (937, 'branches.736'),
#  (938, 'branches.737'),
#  (939, 'branches.738'),
#  (942, 'branches.741'),
#  (944, 'branches.743'),
#  (947, 'branches.746'),
#  (948, 'branches.747'),
#  (949, 'branches.748'),
#  (950, 'branches.749'),
#  (4049, 'foliage1.2899'),
#  (4080, 'foliage1.2930'),
#  (4081, 'foliage1.2931'),
#  (4084, 'foliage1.2934'),
#  (4085, 'foliage1.2935'),
#  ...]

# %%
object_ids.shape
# Out:
# (720, 1280)

# %%
object_ids_cp = object_ids.copy().astype(np.uint8)
cv2.circle(object_ids_cp, (300, 300), 10, 255, 2)
cv2.circle(object_ids_cp, (340, 340), 10, 255, 2)
plt.imshow(object_ids_cp)
plt.axis('off')
plt.show()

object_ids[300, 300], object_ids[340, 340]
# Out:
# (15, 0)

# %%
# reindex the object ids to 0,1,2,...
for i, (id, name) in enumerate(visible_objs):
    visible_objs[i] = (i+1, name)
    object_ids[object_ids == id] = i+1
    print("reindexing id {} to {}".format(id, i+1))

plt.imshow(object_ids)
plt.axis('off')
plt.show()
# Out:
# reindexing id 1 to 1
# reindexing id 3 to 2
# reindexing id 5 to 3
# reindexing id 7 to 4
# reindexing id 14 to 5
# reindexing id 15 to 6
# reindexing id 18 to 7
# reindexing id 21 to 8
# reindexing id 22 to 9
# reindexing id 25 to 10
# reindexing id 29 to 11
# reindexing id 35 to 12
# reindexing id 36 to 13
# reindexing id 39 to 14
# reindexing id 41 to 15
# reindexing id 48 to 16
# reindexing id 54 to 17
# reindexing id 55 to 18
# reindexing id 70 to 19
# reindexing id 74 to 20
# reindexing id 78 to 21
# reindexing id 79 to 22
# reindexing id 89 to 23
# reindexing id 90 to 24
# reindexing id 97 to 25
# reindexing id 101 to 26
# reindexing id 102 to 27
# reindexing id 103 to 28
# reindexing id 119 to 29
# reindexing id 122 to 30
# reindexing id 125 to 31
# reindexing id 132 to 32
# reindexing id 136 to 33
# reindexing id 138 to 34
# reindexing id 152 to 35
# reindexing id 153 to 36
# reindexing id 158 to 37
# reindexing id 163 to 38
# reindexing id 164 to 39
# reindexing id 167 to 40
# reindexing id 171 to 41
# reindexing id 173 to 42
# reindexing id 178 to 43
# reindexing id 183 to 44
# reindexing id 187 to 45
# reindexing id 190 to 46
# reindexing id 194 to 47
# reindexing id 201 to 48
# reindexing id 215 to 49
# reindexing id 258 to 50
# reindexing id 263 to 51
# reindexing id 269 to 52
# reindexing id 270 to 53
# reindexing id 271 to 54
# reindexing id 276 to 55
# reindexing id 294 to 56
# reindexing id 307 to 57
# reindexing id 318 to 58
# reindexing id 319 to 59
# reindexing id 320 to 60
# reindexing id 321 to 61
# reindexing id 322 to 62
# reindexing id 323 to 63
# reindexing id 327 to 64
# reindexing id 328 to 65
# reindexing id 329 to 66
# reindexing id 330 to 67
# reindexing id 331 to 68
# reindexing id 332 to 69
# reindexing id 333 to 70
# reindexing id 334 to 71
# reindexing id 335 to 72
# reindexing id 336 to 73
# reindexing id 337 to 74
# reindexing id 338 to 75
# reindexing id 339 to 76
# reindexing id 340 to 77
# reindexing id 341 to 78
# reindexing id 342 to 79
# reindexing id 343 to 80
# reindexing id 344 to 81
# reindexing id 345 to 82
# reindexing id 346 to 83
# reindexing id 351 to 84
# reindexing id 353 to 85
# reindexing id 355 to 86
# reindexing id 357 to 87
# reindexing id 358 to 88
# reindexing id 359 to 89
# reindexing id 360 to 90
# reindexing id 361 to 91
# reindexing id 362 to 92
# reindexing id 366 to 93
# reindexing id 367 to 94
# reindexing id 368 to 95
# reindexing id 370 to 96
# reindexing id 371 to 97
# reindexing id 372 to 98
# reindexing id 373 to 99
# reindexing id 374 to 100
# reindexing id 375 to 101
# reindexing id 376 to 102
# reindexing id 377 to 103
# reindexing id 378 to 104
# reindexing id 379 to 105
# reindexing id 380 to 106
# reindexing id 381 to 107
# reindexing id 383 to 108
# reindexing id 384 to 109
# reindexing id 385 to 110
# reindexing id 386 to 111
# reindexing id 387 to 112
# reindexing id 388 to 113
# reindexing id 389 to 114
# reindexing id 390 to 115
# reindexing id 392 to 116
# reindexing id 393 to 117
# reindexing id 394 to 118
# reindexing id 395 to 119
# reindexing id 396 to 120
# reindexing id 397 to 121
# reindexing id 398 to 122
# reindexing id 402 to 123
# reindexing id 403 to 124
# reindexing id 404 to 125
# reindexing id 405 to 126
# reindexing id 406 to 127
# reindexing id 407 to 128
# reindexing id 408 to 129
# reindexing id 409 to 130
# reindexing id 411 to 131
# reindexing id 412 to 132
# reindexing id 413 to 133
# reindexing id 414 to 134
# reindexing id 416 to 135
# reindexing id 418 to 136
# reindexing id 419 to 137
# reindexing id 420 to 138
# reindexing id 425 to 139
# reindexing id 426 to 140
# reindexing id 427 to 141
# reindexing id 428 to 142
# reindexing id 431 to 143
# reindexing id 432 to 144
# reindexing id 433 to 145
# reindexing id 437 to 146
# reindexing id 466 to 147
# reindexing id 467 to 148
# reindexing id 472 to 149
# reindexing id 476 to 150
# reindexing id 477 to 151
# reindexing id 478 to 152
# reindexing id 479 to 153
# reindexing id 480 to 154
# reindexing id 481 to 155
# reindexing id 482 to 156
# reindexing id 483 to 157
# reindexing id 484 to 158
# reindexing id 485 to 159
# reindexing id 486 to 160
# reindexing id 487 to 161
# reindexing id 488 to 162
# reindexing id 489 to 163
# reindexing id 490 to 164
# reindexing id 514 to 165
# reindexing id 517 to 166
# reindexing id 518 to 167
# reindexing id 519 to 168
# reindexing id 520 to 169
# reindexing id 521 to 170
# reindexing id 522 to 171
# reindexing id 523 to 172
# reindexing id 524 to 173
# reindexing id 525 to 174
# reindexing id 526 to 175
# reindexing id 527 to 176
# reindexing id 528 to 177
# reindexing id 529 to 178
# reindexing id 530 to 179
# reindexing id 543 to 180
# reindexing id 549 to 181
# reindexing id 550 to 182
# reindexing id 555 to 183
# reindexing id 556 to 184
# reindexing id 557 to 185
# reindexing id 560 to 186
# reindexing id 565 to 187
# reindexing id 566 to 188
# reindexing id 568 to 189
# reindexing id 583 to 190
# reindexing id 596 to 191
# reindexing id 599 to 192
# reindexing id 600 to 193
# reindexing id 601 to 194
# reindexing id 602 to 195
# reindexing id 603 to 196
# reindexing id 604 to 197
# reindexing id 605 to 198
# reindexing id 606 to 199
# reindexing id 607 to 200
# reindexing id 609 to 201
# reindexing id 610 to 202
# reindexing id 616 to 203
# reindexing id 617 to 204
# reindexing id 620 to 205
# reindexing id 621 to 206
# reindexing id 622 to 207
# reindexing id 623 to 208
# reindexing id 631 to 209
# reindexing id 636 to 210
# reindexing id 644 to 211
# reindexing id 645 to 212
# reindexing id 649 to 213
# reindexing id 654 to 214
# reindexing id 659 to 215
# reindexing id 660 to 216
# reindexing id 661 to 217
# reindexing id 662 to 218
# reindexing id 663 to 219
# reindexing id 664 to 220
# reindexing id 665 to 221
# reindexing id 666 to 222
# reindexing id 667 to 223
# reindexing id 668 to 224
# reindexing id 669 to 225
# reindexing id 671 to 226
# reindexing id 673 to 227
# reindexing id 674 to 228
# reindexing id 675 to 229
# reindexing id 683 to 230
# reindexing id 686 to 231
# reindexing id 687 to 232
# reindexing id 688 to 233
# reindexing id 702 to 234
# reindexing id 710 to 235
# reindexing id 712 to 236
# reindexing id 713 to 237
# reindexing id 715 to 238
# reindexing id 718 to 239
# reindexing id 719 to 240
# reindexing id 720 to 241
# reindexing id 723 to 242
# reindexing id 725 to 243
# reindexing id 726 to 244
# reindexing id 727 to 245
# reindexing id 728 to 246
# reindexing id 732 to 247
# reindexing id 733 to 248
# reindexing id 734 to 249
# reindexing id 735 to 250
# reindexing id 736 to 251
# reindexing id 737 to 252
# reindexing id 738 to 253
# reindexing id 740 to 254
# reindexing id 741 to 255
# reindexing id 752 to 256
# reindexing id 753 to 257
# reindexing id 754 to 258
# reindexing id 755 to 259
# reindexing id 756 to 260
# reindexing id 757 to 261
# reindexing id 758 to 262
# reindexing id 765 to 263
# reindexing id 767 to 264
# reindexing id 768 to 265
# reindexing id 772 to 266
# reindexing id 773 to 267
# reindexing id 778 to 268
# reindexing id 779 to 269
# reindexing id 781 to 270
# reindexing id 782 to 271
# reindexing id 783 to 272
# reindexing id 784 to 273
# reindexing id 786 to 274
# reindexing id 788 to 275
# reindexing id 789 to 276
# reindexing id 790 to 277
# reindexing id 791 to 278
# reindexing id 792 to 279
# reindexing id 793 to 280
# reindexing id 794 to 281
# reindexing id 795 to 282
# reindexing id 797 to 283
# reindexing id 798 to 284
# reindexing id 799 to 285
# reindexing id 801 to 286
# reindexing id 806 to 287
# reindexing id 807 to 288
# reindexing id 810 to 289
# reindexing id 811 to 290
# reindexing id 813 to 291
# reindexing id 814 to 292
# reindexing id 815 to 293
# reindexing id 816 to 294
# reindexing id 818 to 295
# reindexing id 819 to 296
# reindexing id 820 to 297
# reindexing id 821 to 298
# reindexing id 823 to 299
# reindexing id 824 to 300
# reindexing id 825 to 301
# reindexing id 826 to 302
# reindexing id 827 to 303
# reindexing id 828 to 304
# reindexing id 829 to 305
# reindexing id 830 to 306
# reindexing id 831 to 307
# reindexing id 832 to 308
# reindexing id 833 to 309
# reindexing id 834 to 310
# reindexing id 846 to 311
# reindexing id 847 to 312
# reindexing id 852 to 313
# reindexing id 856 to 314
# reindexing id 857 to 315
# reindexing id 858 to 316
# reindexing id 859 to 317
# reindexing id 860 to 318
# reindexing id 861 to 319
# reindexing id 863 to 320
# reindexing id 865 to 321
# reindexing id 866 to 322
# reindexing id 868 to 323
# reindexing id 869 to 324
# reindexing id 872 to 325
# reindexing id 873 to 326
# reindexing id 874 to 327
# reindexing id 875 to 328
# reindexing id 876 to 329
# reindexing id 880 to 330
# reindexing id 881 to 331
# reindexing id 882 to 332
# reindexing id 883 to 333
# reindexing id 884 to 334
# reindexing id 885 to 335
# reindexing id 886 to 336
# reindexing id 887 to 337
# reindexing id 888 to 338
# reindexing id 889 to 339
# reindexing id 890 to 340
# reindexing id 894 to 341
# reindexing id 896 to 342
# reindexing id 898 to 343
# reindexing id 899 to 344
# reindexing id 900 to 345
# reindexing id 901 to 346
# reindexing id 902 to 347
# reindexing id 903 to 348
# reindexing id 905 to 349
# reindexing id 908 to 350
# reindexing id 909 to 351
# reindexing id 910 to 352
# reindexing id 911 to 353
# reindexing id 913 to 354
# reindexing id 916 to 355
# reindexing id 919 to 356
# reindexing id 921 to 357
# reindexing id 922 to 358
# reindexing id 924 to 359
# reindexing id 926 to 360
# reindexing id 927 to 361
# reindexing id 928 to 362
# reindexing id 929 to 363
# reindexing id 930 to 364
# reindexing id 931 to 365
# reindexing id 932 to 366
# reindexing id 933 to 367
# reindexing id 934 to 368
# reindexing id 935 to 369
# reindexing id 936 to 370
# reindexing id 937 to 371
# reindexing id 938 to 372
# reindexing id 939 to 373
# reindexing id 942 to 374
# reindexing id 944 to 375
# reindexing id 947 to 376
# reindexing id 948 to 377
# reindexing id 949 to 378
# reindexing id 950 to 379
# reindexing id 953 to 380
# reindexing id 976 to 381
# reindexing id 977 to 382
# reindexing id 979 to 383
# reindexing id 982 to 384
# reindexing id 984 to 385
# reindexing id 986 to 386
# reindexing id 987 to 387
# reindexing id 990 to 388
# reindexing id 991 to 389
# reindexing id 992 to 390
# reindexing id 996 to 391
# reindexing id 997 to 392
# reindexing id 998 to 393
# reindexing id 1002 to 394
# reindexing id 1019 to 395
# reindexing id 1029 to 396
# reindexing id 1034 to 397
# reindexing id 1036 to 398
# reindexing id 1037 to 399
# reindexing id 1038 to 400
# reindexing id 1041 to 401
# reindexing id 1042 to 402
# reindexing id 1043 to 403
# reindexing id 1044 to 404
# reindexing id 1045 to 405
# reindexing id 1046 to 406
# reindexing id 1047 to 407
# reindexing id 1049 to 408
# reindexing id 1050 to 409
# reindexing id 1051 to 410
# reindexing id 1052 to 411
# reindexing id 1053 to 412
# reindexing id 1054 to 413
# reindexing id 1055 to 414
# reindexing id 1057 to 415
# reindexing id 1058 to 416
# reindexing id 1068 to 417
# reindexing id 1069 to 418
# reindexing id 1076 to 419
# reindexing id 1081 to 420
# reindexing id 1452 to 421
# reindexing id 1746 to 422
# reindexing id 1749 to 423
# reindexing id 1752 to 424
# reindexing id 1918 to 425
# reindexing id 1919 to 426
# reindexing id 1920 to 427
# reindexing id 1947 to 428
# reindexing id 1948 to 429
# reindexing id 1949 to 430
# reindexing id 1950 to 431
# reindexing id 1951 to 432
# reindexing id 1967 to 433
# reindexing id 1973 to 434
# reindexing id 1989 to 435
# reindexing id 1990 to 436
# reindexing id 1995 to 437
# reindexing id 1998 to 438
# reindexing id 1999 to 439
# reindexing id 2000 to 440
# reindexing id 2001 to 441
# reindexing id 2038 to 442
# reindexing id 2043 to 443
# reindexing id 2044 to 444
# reindexing id 2046 to 445
# reindexing id 2062 to 446
# reindexing id 2069 to 447
# reindexing id 2070 to 448
# reindexing id 2345 to 449
# reindexing id 2346 to 450
# reindexing id 2347 to 451
# reindexing id 2349 to 452
# reindexing id 2350 to 453
# reindexing id 2351 to 454
# reindexing id 2352 to 455
# reindexing id 2353 to 456
# reindexing id 2354 to 457
# reindexing id 2355 to 458
# reindexing id 2356 to 459
# reindexing id 2357 to 460
# reindexing id 2358 to 461
# reindexing id 2359 to 462
# reindexing id 2360 to 463
# reindexing id 2361 to 464
# reindexing id 2362 to 465
# reindexing id 2363 to 466
# reindexing id 2364 to 467
# reindexing id 2365 to 468
# reindexing id 2366 to 469
# reindexing id 2367 to 470
# reindexing id 2368 to 471
# reindexing id 2369 to 472
# reindexing id 2370 to 473
# reindexing id 2371 to 474
# reindexing id 2372 to 475
# reindexing id 2373 to 476
# reindexing id 2374 to 477
# reindexing id 2375 to 478
# reindexing id 2376 to 479
# reindexing id 2377 to 480
# reindexing id 2378 to 481
# reindexing id 2379 to 482
# reindexing id 2380 to 483
# reindexing id 2381 to 484
# reindexing id 2382 to 485
# reindexing id 2383 to 486
# reindexing id 2384 to 487
# reindexing id 2385 to 488
# reindexing id 2386 to 489
# reindexing id 2387 to 490
# reindexing id 2388 to 491
# reindexing id 2389 to 492
# reindexing id 2390 to 493
# reindexing id 2391 to 494
# reindexing id 2392 to 495
# reindexing id 2393 to 496
# reindexing id 2394 to 497
# reindexing id 2395 to 498
# reindexing id 2396 to 499
# reindexing id 2397 to 500
# reindexing id 2398 to 501
# reindexing id 2399 to 502
# reindexing id 2400 to 503
# reindexing id 2401 to 504
# reindexing id 2402 to 505
# reindexing id 2403 to 506
# reindexing id 2404 to 507
# reindexing id 2405 to 508
# reindexing id 2406 to 509
# reindexing id 2407 to 510
# reindexing id 2408 to 511
# reindexing id 2409 to 512
# reindexing id 2410 to 513
# reindexing id 2411 to 514
# reindexing id 2412 to 515
# reindexing id 2413 to 516
# reindexing id 2414 to 517
# reindexing id 2415 to 518
# reindexing id 2417 to 519
# reindexing id 2418 to 520
# reindexing id 2419 to 521
# reindexing id 2421 to 522
# reindexing id 2422 to 523
# reindexing id 2423 to 524
# reindexing id 2424 to 525
# reindexing id 2425 to 526
# reindexing id 2426 to 527
# reindexing id 2429 to 528
# reindexing id 2430 to 529
# reindexing id 2431 to 530
# reindexing id 2432 to 531
# reindexing id 2433 to 532
# reindexing id 2435 to 533
# reindexing id 2436 to 534
# reindexing id 2437 to 535
# reindexing id 2438 to 536
# reindexing id 2439 to 537
# reindexing id 2441 to 538
# reindexing id 2442 to 539
# reindexing id 2454 to 540
# reindexing id 2456 to 541
# reindexing id 2457 to 542
# reindexing id 2458 to 543
# reindexing id 2459 to 544
# reindexing id 2460 to 545
# reindexing id 2461 to 546
# reindexing id 2462 to 547
# reindexing id 2484 to 548
# reindexing id 2485 to 549
# reindexing id 2487 to 550
# reindexing id 2488 to 551
# reindexing id 2489 to 552
# reindexing id 2490 to 553
# reindexing id 2491 to 554
# reindexing id 2492 to 555
# reindexing id 3025 to 779
# reindexing id 3027 to 780
# reindexing id 3028 to 781
# reindexing id 3048 to 782
# reindexing id 3049 to 783
# reindexing id 3050 to 784
# reindexing id 3105 to 785
# reindexing id 3109 to 786
# reindexing id 3111 to 787
# reindexing id 3112 to 788
# reindexing id 3118 to 789
# reindexing id 3119 to 790
# reindexing id 3120 to 791
# reindexing id 3121 to 792
# reindexing id 3122 to 793
# reindexing id 3123 to 794
# reindexing id 3125 to 795
# reindexing id 3126 to 796
# reindexing id 3127 to 797
# reindexing id 3129 to 798
# reindexing id 3130 to 799
# reindexing id 3131 to 800
# reindexing id 3132 to 801
# reindexing id 3133 to 802
# reindexing id 3134 to 803
# reindexing id 3135 to 804
# reindexing id 3139 to 805
# reindexing id 3141 to 806
# reindexing id 3151 to 807
# reindexing id 3157 to 808
# reindexing id 3158 to 809
# reindexing id 3159 to 810
# reindexing id 3160 to 811
# reindexing id 3161 to 812
# reindexing id 3162 to 813
# reindexing id 3163 to 814
# reindexing id 3164 to 815
# reindexing id 3165 to 816
# reindexing id 3166 to 817
# reindexing id 3188 to 818
# reindexing id 3296 to 819
# reindexing id 3300 to 820
# reindexing id 3301 to 821
# reindexing id 3302 to 822
# reindexing id 3303 to 823
# reindexing id 3304 to 824
# reindexing id 3306 to 825
# reindexing id 3307 to 826
# reindexing id 3308 to 827
# reindexing id 3309 to 828
# reindexing id 3345 to 829
# reindexing id 3346 to 830
# reindexing id 3348 to 831
# reindexing id 3350 to 832
# reindexing id 3375 to 833
# reindexing id 3376 to 834
# reindexing id 3381 to 835
# reindexing id 3382 to 836
# reindexing id 3384 to 837
# reindexing id 3385 to 838
# reindexing id 3386 to 839
# reindexing id 3387 to 840
# reindexing id 3388 to 841
# reindexing id 3392 to 842
# reindexing id 3393 to 843
# reindexing id 3394 to 844
# reindexing id 3395 to 845
# reindexing id 3399 to 846
# reindexing id 3400 to 847
# reindexing id 3401 to 848
# reindexing id 3402 to 849
# reindexing id 3403 to 850
# reindexing id 3404 to 851
# reindexing id 3405 to 852
# reindexing id 3406 to 853
# reindexing id 3407 to 854
# reindexing id 3408 to 855
# reindexing id 3409 to 856
# reindexing id 3410 to 857
# reindexing id 3411 to 858
# reindexing id 3412 to 859
# reindexing id 3413 to 860
# reindexing id 3414 to 861
# reindexing id 3415 to 862
# reindexing id 3420 to 863
# reindexing id 3421 to 864
# reindexing id 3422 to 865
# reindexing id 3423 to 866
# reindexing id 3424 to 867
# reindexing id 3425 to 868
# reindexing id 3426 to 869
# reindexing id 3427 to 870
# reindexing id 3428 to 871
# reindexing id 3429 to 872
# reindexing id 3430 to 873
# reindexing id 3431 to 874
# reindexing id 3433 to 875
# reindexing id 3435 to 876
# reindexing id 3440 to 877
# reindexing id 3442 to 878
# reindexing id 3444 to 879
# reindexing id 3445 to 880
# reindexing id 3450 to 881
# reindexing id 3451 to 882
# reindexing id 3452 to 883
# reindexing id 3453 to 884
# reindexing id 3454 to 885
# reindexing id 3456 to 886
# reindexing id 3457 to 887
# reindexing id 3462 to 888
# reindexing id 3463 to 889
# reindexing id 3464 to 890
# reindexing id 3465 to 891
# reindexing id 3466 to 892
# reindexing id 3467 to 893
# reindexing id 3468 to 894
# reindexing id 3469 to 895
# reindexing id 3470 to 896
# reindexing id 3471 to 897
# reindexing id 3472 to 898
# reindexing id 3473 to 899
# reindexing id 3474 to 900
# reindexing id 3475 to 901
# reindexing id 3476 to 902
# reindexing id 3477 to 903
# reindexing id 3478 to 904
# reindexing id 3479 to 905
# reindexing id 3480 to 906
# reindexing id 3481 to 907
# reindexing id 3482 to 908
# reindexing id 3483 to 909
# reindexing id 3484 to 910
# reindexing id 3485 to 911
# reindexing id 3486 to 912
# reindexing id 3487 to 913
# reindexing id 3489 to 914
# reindexing id 3490 to 915
# reindexing id 3491 to 916
# reindexing id 3493 to 917
# reindexing id 3494 to 918
# reindexing id 3496 to 919
# reindexing id 3497 to 920
# reindexing id 3498 to 921
# reindexing id 3499 to 922
# reindexing id 3501 to 923
# reindexing id 3502 to 924
# reindexing id 3504 to 925
# reindexing id 3505 to 926
# reindexing id 3506 to 927
# reindexing id 3507 to 928
# reindexing id 3508 to 929
# reindexing id 3509 to 930
# reindexing id 3510 to 931
# reindexing id 3511 to 932
# reindexing id 3512 to 933
# reindexing id 3513 to 934
# reindexing id 3514 to 935
# reindexing id 3515 to 936
# reindexing id 3516 to 937
# reindexing id 3517 to 938
# reindexing id 3518 to 939
# reindexing id 3520 to 940
# reindexing id 3521 to 941
# reindexing id 3522 to 942
# reindexing id 3523 to 943
# reindexing id 3526 to 944
# reindexing id 3528 to 945
# reindexing id 3529 to 946
# reindexing id 3530 to 947
# reindexing id 3531 to 948
# reindexing id 3532 to 949
# reindexing id 3533 to 950
# reindexing id 3534 to 951
# reindexing id 3535 to 952
# reindexing id 3536 to 953
# reindexing id 3537 to 954
# reindexing id 3538 to 955
# reindexing id 3539 to 956
# reindexing id 3540 to 957
# reindexing id 3541 to 958
# reindexing id 3542 to 959
# reindexing id 3543 to 960
# reindexing id 3544 to 961
# reindexing id 3545 to 962
# reindexing id 3546 to 963
# reindexing id 3547 to 964
# reindexing id 3548 to 965
# reindexing id 3549 to 966
# reindexing id 3689 to 967
# reindexing id 3718 to 968
# reindexing id 3719 to 969
# reindexing id 3720 to 970
# reindexing id 3721 to 971
# reindexing id 3722 to 972
# reindexing id 3726 to 973
# reindexing id 3839 to 974
# reindexing id 3844 to 975
# reindexing id 3880 to 976
# reindexing id 3887 to 977
# reindexing id 3888 to 978
# reindexing id 3891 to 979
# reindexing id 3894 to 980
# reindexing id 3896 to 981
# reindexing id 3899 to 982
# reindexing id 3917 to 983
# reindexing id 3918 to 984
# reindexing id 3919 to 985
# reindexing id 3925 to 986
# reindexing id 3934 to 987
# reindexing id 4008 to 988
# reindexing id 4009 to 989
# reindexing id 4012 to 990
# reindexing id 4013 to 991
# reindexing id 4036 to 992
# reindexing id 4045 to 993
# reindexing id 4046 to 994
# reindexing id 4048 to 995
# reindexing id 4049 to 996
# reindexing id 4080 to 997
# reindexing id 4081 to 998
# reindexing id 4084 to 999
# reindexing id 4085 to 1000
# reindexing id 4086 to 1001
# reindexing id 4088 to 1002
# reindexing id 4089 to 1003
# reindexing id 4090 to 1004
# reindexing id 4102 to 1005
# reindexing id 4103 to 1006
# reindexing id 4106 to 1007
# reindexing id 4108 to 1008
# reindexing id 4210 to 1009
# reindexing id 4211 to 1010
# reindexing id 4213 to 1011
# reindexing id 4214 to 1012
# reindexing id 4215 to 1013
# reindexing id 4216 to 1014
# reindexing id 4220 to 1015
# reindexing id 4222 to 1016
# reindexing id 4223 to 1017
# reindexing id 4229 to 1018
# reindexing id 4236 to 1019
# reindexing id 4238 to 1020
# reindexing id 4241 to 1021
# reindexing id 4242 to 1022
# reindexing id 4244 to 1023
# reindexing id 4249 to 1024
# reindexing id 4250 to 1025
# reindexing id 4252 to 1026
# reindexing id 4253 to 1027
# reindexing id 4255 to 1028
# reindexing id 4256 to 1029
# reindexing id 4257 to 1030
# reindexing id 4258 to 1031
# reindexing id 4260 to 1032
# reindexing id 4261 to 1033
# reindexing id 4265 to 1034
# reindexing id 4266 to 1035
# reindexing id 4267 to 1036
# reindexing id 4269 to 1037
# reindexing id 4271 to 1038
# reindexing id 4273 to 1039
# reindexing id 4275 to 1040
# reindexing id 4285 to 1041
# reindexing id 4286 to 1042
# reindexing id 4287 to 1043
# reindexing id 4289 to 1044
# reindexing id 4290 to 1045
# reindexing id 4294 to 1046
# reindexing id 4296 to 1047
# reindexing id 4297 to 1048
# reindexing id 4298 to 1049
# reindexing id 4299 to 1050
# reindexing id 4301 to 1051
# reindexing id 4307 to 1052
# reindexing id 4308 to 1053
# reindexing id 4335 to 1054
# reindexing id 4336 to 1055
# reindexing id 4340 to 1056
# reindexing id 4341 to 1057
# reindexing id 4342 to 1058
# reindexing id 4343 to 1059
# reindexing id 4344 to 1060
# reindexing id 4345 to 1061
# reindexing id 4346 to 1062
# reindexing id 4347 to 1063
# reindexing id 4350 to 1064
# reindexing id 4356 to 1065
# reindexing id 4363 to 1066
# reindexing id 4368 to 1067
# reindexing id 4370 to 1068
# reindexing id 4400 to 1069
# reindexing id 4404 to 1070
# reindexing id 4405 to 1071
# reindexing id 4406 to 1072
# reindexing id 4407 to 1073
# reindexing id 4429 to 1074
# reindexing id 4431 to 1075
# reindexing id 4433 to 1076
# reindexing id 4434 to 1077
# reindexing id 4435 to 1078
# reindexing id 4439 to 1079
# reindexing id 4515 to 1080
# reindexing id 4518 to 1081
# reindexing id 4519 to 1082
# reindexing id 4520 to 1083
# reindexing id 4546 to 1084
# reindexing id 4547 to 1085
# reindexing id 4603 to 1086
# reindexing id 4604 to 1087
# reindexing id 4605 to 1088
# reindexing id 4606 to 1089
# reindexing id 4608 to 1090
# reindexing id 4609 to 1091
# reindexing id 4610 to 1092
# reindexing id 4611 to 1093
# reindexing id 4612 to 1094
# reindexing id 4628 to 1095
# reindexing id 4629 to 1096
# reindexing id 4630 to 1097
# reindexing id 4631 to 1098
# reindexing id 4634 to 1099
# reindexing id 4635 to 1100
# reindexing id 4636 to 1101
# reindexing id 4638 to 1102
# reindexing id 4639 to 1103
# reindexing id 4641 to 1104
# reindexing id 4642 to 1105
# reindexing id 4643 to 1106
# reindexing id 4645 to 1107
# reindexing id 4646 to 1108
# reindexing id 4647 to 1109
# reindexing id 4649 to 1110
# reindexing id 4652 to 1111
# reindexing id 4653 to 1112
# reindexing id 4654 to 1113
# reindexing id 4655 to 1114
# reindexing id 4656 to 1115
# reindexing id 4657 to 1116
# reindexing id 4658 to 1117
# reindexing id 4660 to 1118
# reindexing id 4662 to 1119
# reindexing id 4664 to 1120
# reindexing id 4665 to 1121
# reindexing id 4666 to 1122
# reindexing id 4667 to 1123
# reindexing id 4669 to 1124
# reindexing id 4670 to 1125
# reindexing id 4671 to 1126
# reindexing id 4672 to 1127
# reindexing id 4674 to 1128
# reindexing id 4675 to 1129
# reindexing id 4676 to 1130
# reindexing id 4677 to 1131
# reindexing id 4678 to 1132
# reindexing id 4679 to 1133
# reindexing id 4680 to 1134
# reindexing id 4681 to 1135
# reindexing id 4682 to 1136
# reindexing id 4683 to 1137
# reindexing id 4684 to 1138
# reindexing id 4686 to 1139
# reindexing id 4689 to 1140
# reindexing id 4692 to 1141
# reindexing id 4693 to 1142
# reindexing id 4694 to 1143
# reindexing id 4695 to 1144
# reindexing id 4696 to 1145
# reindexing id 4697 to 1146
# reindexing id 4698 to 1147
# reindexing id 4699 to 1148
# reindexing id 4700 to 1149
# reindexing id 4701 to 1150
# reindexing id 4702 to 1151
# reindexing id 4703 to 1152
# reindexing id 4704 to 1153
# reindexing id 4705 to 1154
# reindexing id 4706 to 1155
# reindexing id 4707 to 1156
# reindexing id 4708 to 1157
# reindexing id 4709 to 1158
# reindexing id 4710 to 1159
# reindexing id 4711 to 1160
# reindexing id 4712 to 1161
# reindexing id 4728 to 1162
# reindexing id 4767 to 1163
# reindexing id 4768 to 1164
# reindexing id 4769 to 1165
# reindexing id 4771 to 1166
# reindexing id 4772 to 1167
# reindexing id 4773 to 1168
# reindexing id 4774 to 1169
# reindexing id 4799 to 1170
# reindexing id 4800 to 1171
# reindexing id 4801 to 1172
# reindexing id 4802 to 1173
# reindexing id 4803 to 1174
# reindexing id 4804 to 1175
# reindexing id 4812 to 1176
# reindexing id 4814 to 1177
# reindexing id 4838 to 1178
# reindexing id 4841 to 1179
# reindexing id 4845 to 1180
# reindexing id 4846 to 1181
# reindexing id 4848 to 1182
# reindexing id 4851 to 1183
# reindexing id 4852 to 1184
# reindexing id 4853 to 1185
# reindexing id 4857 to 1186
# reindexing id 4859 to 1187
# reindexing id 4864 to 1188
# reindexing id 4866 to 1189
# reindexing id 4867 to 1190
# reindexing id 4868 to 1191
# reindexing id 4869 to 1192
# reindexing id 4871 to 1193
# reindexing id 4878 to 1194
# reindexing id 4883 to 1195
# reindexing id 4886 to 1196
# reindexing id 4887 to 1197
# reindexing id 4888 to 1198
# reindexing id 4889 to 1199
# reindexing id 4891 to 1200
# reindexing id 4979 to 1201
# reindexing id 4980 to 1202
# reindexing id 4981 to 1203
# reindexing id 4982 to 1204
# reindexing id 4983 to 1205
# reindexing id 4984 to 1206
# reindexing id 4985 to 1207
# reindexing id 4986 to 1208
# reindexing id 5022 to 1209
# reindexing id 5037 to 1210
# reindexing id 5039 to 1211
# reindexing id 5041 to 1212
# reindexing id 5042 to 1213
# reindexing id 5053 to 1214
# reindexing id 5054 to 1215
# reindexing id 5055 to 1216
# reindexing id 5056 to 1217
# reindexing id 5057 to 1218
# reindexing id 5060 to 1219
# reindexing id 5061 to 1220
# reindexing id 5067 to 1221
# reindexing id 5069 to 1222
# reindexing id 5070 to 1223
# reindexing id 5071 to 1224
# reindexing id 5072 to 1225
# reindexing id 5073 to 1226
# reindexing id 5074 to 1227
# reindexing id 5078 to 1228
# reindexing id 5080 to 1229
# reindexing id 5099 to 1230
# reindexing id 5100 to 1231
# reindexing id 5101 to 1232
# reindexing id 5103 to 1233
# reindexing id 5104 to 1234
# reindexing id 5105 to 1235
# reindexing id 5106 to 1236
# reindexing id 5107 to 1237
# reindexing id 5108 to 1238
# reindexing id 5110 to 1239
# reindexing id 5111 to 1240
# reindexing id 5112 to 1241
# reindexing id 5113 to 1242
# reindexing id 5114 to 1243
# reindexing id 5115 to 1244
# reindexing id 5116 to 1245
# reindexing id 5118 to 1246
# reindexing id 5121 to 1247
# reindexing id 5123 to 1248
# reindexing id 5124 to 1249
# reindexing id 5125 to 1250
# reindexing id 5126 to 1251
# reindexing id 5127 to 1252
# reindexing id 5129 to 1253
# reindexing id 5130 to 1254
# reindexing id 5131 to 1255
# reindexing id 5133 to 1256
# reindexing id 5134 to 1257
# reindexing id 5137 to 1258
# reindexing id 5138 to 1259
# reindexing id 5144 to 1260
# reindexing id 5148 to 1261
# reindexing id 5149 to 1262
# reindexing id 5150 to 1263
# reindexing id 5235 to 1264
# reindexing id 5236 to 1265
# reindexing id 5237 to 1266
# reindexing id 5239 to 1267
# reindexing id 5240 to 1268
# reindexing id 5241 to 1269
# reindexing id 5242 to 1270
# reindexing id 5248 to 1271
# reindexing id 5249 to 1272
# reindexing id 5250 to 1273
# reindexing id 5251 to 1274
# reindexing id 5252 to 1275
# reindexing id 5256 to 1276
# reindexing id 5259 to 1277
# reindexing id 5260 to 1278
# reindexing id 5261 to 1279
# reindexing id 5263 to 1280
# reindexing id 5265 to 1281
# reindexing id 5266 to 1282
# reindexing id 5268 to 1283
# reindexing id 5269 to 1284
# reindexing id 5271 to 1285
# reindexing id 5273 to 1286
# reindexing id 5281 to 1287
# reindexing id 5282 to 1288
# reindexing id 5284 to 1289
# reindexing id 5286 to 1290
# reindexing id 5287 to 1291
# reindexing id 5288 to 1292
# reindexing id 5297 to 1293
# reindexing id 5308 to 1294
# reindexing id 5309 to 1295
# reindexing id 5312 to 1296
# reindexing id 5330 to 1297
# reindexing id 5331 to 1298
# reindexing id 5332 to 1299
# reindexing id 5336 to 1300
# reindexing id 5337 to 1301
# reindexing id 5377 to 1302
# reindexing id 5382 to 1303
# reindexing id 5384 to 1304
# reindexing id 5386 to 1305
# reindexing id 5387 to 1306
# reindexing id 5391 to 1307
# reindexing id 5394 to 1308
# reindexing id 5396 to 1309
# reindexing id 5399 to 1310
# reindexing id 5403 to 1311
# reindexing id 5407 to 1312
# reindexing id 5408 to 1313
# reindexing id 5410 to 1314
# reindexing id 5414 to 1315
# reindexing id 5415 to 1316
# reindexing id 5420 to 1317
# reindexing id 5446 to 1318
# reindexing id 5449 to 1319
# reindexing id 5458 to 1320
# reindexing id 5460 to 1321
# reindexing id 5461 to 1322
# reindexing id 5462 to 1323
# reindexing id 5463 to 1324
# reindexing id 5477 to 1325
# reindexing id 5482 to 1326
# reindexing id 5484 to 1327
# reindexing id 5486 to 1328
# reindexing id 5487 to 1329
# reindexing id 5491 to 1330
# reindexing id 5497 to 1331
# reindexing id 5498 to 1332
# reindexing id 5507 to 1333
# reindexing id 5511 to 1334
# reindexing id 5512 to 1335
# reindexing id 5522 to 1336
# reindexing id 5525 to 1337
# reindexing id 5533 to 1338
# reindexing id 5537 to 1339
# reindexing id 5542 to 1340
# reindexing id 5543 to 1341
# reindexing id 5544 to 1342
# reindexing id 5546 to 1343
# reindexing id 5554 to 1344
# reindexing id 5560 to 1345
# reindexing id 5561 to 1346
# reindexing id 5562 to 1347
# reindexing id 5568 to 1348
# reindexing id 5576 to 1349
# reindexing id 5579 to 1350
# reindexing id 5581 to 1351
# reindexing id 5592 to 1352
# reindexing id 5594 to 1353
# reindexing id 5598 to 1354
# reindexing id 5601 to 1355
# reindexing id 5602 to 1356
# reindexing id 5603 to 1357
# reindexing id 5604 to 1358
# reindexing id 5605 to 1359
# reindexing id 5615 to 1360
# reindexing id 5617 to 1361
# reindexing id 5620 to 1362
# reindexing id 5621 to 1363
# reindexing id 5622 to 1364
# reindexing id 5625 to 1365
# reindexing id 5626 to 1366
# reindexing id 5627 to 1367
# reindexing id 5629 to 1368
# reindexing id 5630 to 1369
# reindexing id 5631 to 1370
# reindexing id 5632 to 1371
# reindexing id 5638 to 1372
# reindexing id 5640 to 1373
# reindexing id 5644 to 1374
# reindexing id 5645 to 1375
# reindexing id 5646 to 1376
# reindexing id 5649 to 1377
# reindexing id 5650 to 1378
# reindexing id 5653 to 1379
# reindexing id 5655 to 1380
# reindexing id 5656 to 1381
# reindexing id 5657 to 1382
# reindexing id 5658 to 1383
# reindexing id 5660 to 1384
# reindexing id 5661 to 1385
# reindexing id 5662 to 1386
# reindexing id 5663 to 1387
# reindexing id 5664 to 1388
# reindexing id 5665 to 1389
# reindexing id 5666 to 1390
# reindexing id 5667 to 1391
# reindexing id 5668 to 1392
# reindexing id 5669 to 1393
# reindexing id 5670 to 1394
# reindexing id 5688 to 1395
# reindexing id 5689 to 1396
# reindexing id 5690 to 1397
# reindexing id 5691 to 1398
# reindexing id 5692 to 1399
# reindexing id 5694 to 1400
# reindexing id 5696 to 1401
# reindexing id 5697 to 1402
# reindexing id 5698 to 1403
# reindexing id 5722 to 1404
# reindexing id 5723 to 1405
# reindexing id 5724 to 1406
# reindexing id 5725 to 1407
# reindexing id 5727 to 1408
# reindexing id 5740 to 1409
# reindexing id 5741 to 1410
# reindexing id 5743 to 1411
# reindexing id 5744 to 1412
# reindexing id 5745 to 1413
# reindexing id 5748 to 1414
# reindexing id 5749 to 1415
# reindexing id 5750 to 1416
# reindexing id 5751 to 1417
# reindexing id 5752 to 1418
# reindexing id 5754 to 1419
# reindexing id 5755 to 1420
# reindexing id 5756 to 1421
# reindexing id 5757 to 1422
# reindexing id 5758 to 1423
# reindexing id 5759 to 1424
# reindexing id 5761 to 1425
# reindexing id 5762 to 1426
# reindexing id 5763 to 1427
# reindexing id 5764 to 1428
# reindexing id 5767 to 1429
# reindexing id 5777 to 1430
# reindexing id 5779 to 1431
# reindexing id 5783 to 1432
# reindexing id 5784 to 1433
# reindexing id 5786 to 1434
# reindexing id 5787 to 1435
# reindexing id 5789 to 1436
# reindexing id 5792 to 1437
# reindexing id 5794 to 1438
# reindexing id 5798 to 1439
# reindexing id 5800 to 1440
# reindexing id 5802 to 1441
# reindexing id 5804 to 1442
# reindexing id 5806 to 1443
# reindexing id 5807 to 1444
# reindexing id 5808 to 1445
# reindexing id 5811 to 1446
# reindexing id 5812 to 1447
# reindexing id 5813 to 1448
# reindexing id 5817 to 1449
# reindexing id 5818 to 1450
# reindexing id 5822 to 1451
# reindexing id 5830 to 1452
# reindexing id 5836 to 1453
# reindexing id 5837 to 1454
# reindexing id 5839 to 1455
# reindexing id 5841 to 1456
# reindexing id 5842 to 1457
# reindexing id 5843 to 1458
# reindexing id 5844 to 1459
# reindexing id 5847 to 1460
# reindexing id 5851 to 1461
# reindexing id 5852 to 1462
# reindexing id 5854 to 1463
# reindexing id 5855 to 1464
# reindexing id 5856 to 1465
# reindexing id 5857 to 1466
# reindexing id 5864 to 1467
# reindexing id 5865 to 1468
# reindexing id 5948 to 1469
# reindexing id 5950 to 1470
# reindexing id 5951 to 1471
# reindexing id 5952 to 1472
# reindexing id 5953 to 1473
# reindexing id 5954 to 1474
# reindexing id 5957 to 1475
# reindexing id 5958 to 1476
# reindexing id 5970 to 1477
# reindexing id 5972 to 1478
# reindexing id 5978 to 1479
# reindexing id 5979 to 1480
# reindexing id 5982 to 1481
# reindexing id 5985 to 1482
# reindexing id 5995 to 1483
# reindexing id 6008 to 1484
# reindexing id 6013 to 1485
# reindexing id 6016 to 1486
# reindexing id 6018 to 1487
# reindexing id 6026 to 1488
# reindexing id 6027 to 1489
# reindexing id 6028 to 1490
# reindexing id 6029 to 1491
# reindexing id 6030 to 1492
# reindexing id 6031 to 1493
# reindexing id 6033 to 1494
# reindexing id 6034 to 1495
# reindexing id 6035 to 1496
# reindexing id 6036 to 1497
# reindexing id 6039 to 1498
# reindexing id 6046 to 1499
# reindexing id 6047 to 1500
# reindexing id 6048 to 1501
# reindexing id 6052 to 1502
# reindexing id 6053 to 1503
# reindexing id 6054 to 1504
# reindexing id 6055 to 1505
# reindexing id 6056 to 1506
# reindexing id 6057 to 1507
# reindexing id 6059 to 1508
# reindexing id 6060 to 1509
# reindexing id 6061 to 1510
# reindexing id 6062 to 1511
# reindexing id 6063 to 1512
# reindexing id 6083 to 1513
# reindexing id 6084 to 1514
# reindexing id 6087 to 1515
# reindexing id 6088 to 1516
# reindexing id 6089 to 1517
# reindexing id 6090 to 1518
# reindexing id 6091 to 1519
# reindexing id 6092 to 1520
# reindexing id 6093 to 1521
# reindexing id 6095 to 1522
# reindexing id 6096 to 1523
# reindexing id 6098 to 1524
# reindexing id 6104 to 1525
# reindexing id 6106 to 1526
# reindexing id 6107 to 1527
# reindexing id 6108 to 1528
# reindexing id 6109 to 1529
# reindexing id 6110 to 1530
# reindexing id 6111 to 1531
# reindexing id 6112 to 1532
# reindexing id 6113 to 1533
# reindexing id 6114 to 1534
# reindexing id 6129 to 1535
# reindexing id 6133 to 1536
# reindexing id 6134 to 1537
# reindexing id 6135 to 1538
# reindexing id 6136 to 1539
# reindexing id 6137 to 1540
# reindexing id 6138 to 1541
# reindexing id 6139 to 1542
# reindexing id 6140 to 1543
# reindexing id 6144 to 1544
# reindexing id 6145 to 1545
# reindexing id 6162 to 1546
# reindexing id 6166 to 1547
# reindexing id 6167 to 1548
# reindexing id 6168 to 1549
# reindexing id 6169 to 1550
# reindexing id 6170 to 1551
# reindexing id 6173 to 1552
# reindexing id 6174 to 1553
# reindexing id 6176 to 1554
# reindexing id 6179 to 1555
# reindexing id 6180 to 1556
# reindexing id 6181 to 1557
# reindexing id 6182 to 1558
# reindexing id 6190 to 1559
# reindexing id 6191 to 1560
# reindexing id 6193 to 1561
# reindexing id 6195 to 1562
# reindexing id 6196 to 1563
# reindexing id 6197 to 1564
# reindexing id 6208 to 1565
# reindexing id 6212 to 1566
# reindexing id 6213 to 1567
# reindexing id 6214 to 1568
# reindexing id 6215 to 1569
# reindexing id 6216 to 1570
# reindexing id 6236 to 1571
# reindexing id 6245 to 1572
# reindexing id 6247 to 1573
# reindexing id 6249 to 1574
# reindexing id 6253 to 1575
# reindexing id 6254 to 1576
# reindexing id 6263 to 1577
# reindexing id 6269 to 1578
# reindexing id 6272 to 1579
# reindexing id 6274 to 1580
# reindexing id 6275 to 1581
# reindexing id 6276 to 1582
# reindexing id 6277 to 1583
# reindexing id 6279 to 1584
# reindexing id 6285 to 1585
# reindexing id 6286 to 1586
# reindexing id 6287 to 1587
# reindexing id 6288 to 1588
# reindexing id 6289 to 1589
# reindexing id 6291 to 1590
# reindexing id 6294 to 1591
# reindexing id 6295 to 1592
# reindexing id 6296 to 1593
# reindexing id 6300 to 1594
# reindexing id 6301 to 1595
# reindexing id 6302 to 1596
# reindexing id 6303 to 1597
# reindexing id 6305 to 1598
# reindexing id 6307 to 1599
# reindexing id 6310 to 1600
# reindexing id 6311 to 1601
# reindexing id 6312 to 1602
# reindexing id 6313 to 1603
# reindexing id 6322 to 1604
# reindexing id 6326 to 1605
# reindexing id 6328 to 1606
# reindexing id 6329 to 1607
# reindexing id 6330 to 1608
# reindexing id 6331 to 1609
# reindexing id 6333 to 1610
# reindexing id 6335 to 1611
# reindexing id 6338 to 1612
# reindexing id 6339 to 1613
# reindexing id 6341 to 1614
# reindexing id 6342 to 1615
# reindexing id 6343 to 1616
# reindexing id 6345 to 1617
# reindexing id 6354 to 1618
# reindexing id 6355 to 1619
# reindexing id 6356 to 1620
# reindexing id 6360 to 1621
# reindexing id 6364 to 1622
# reindexing id 6365 to 1623
# reindexing id 6369 to 1624
# reindexing id 6370 to 1625
# reindexing id 6371 to 1626
# reindexing id 6372 to 1627
# reindexing id 6373 to 1628
# reindexing id 6374 to 1629
# reindexing id 6378 to 1630
# reindexing id 6381 to 1631
# reindexing id 6387 to 1632
# reindexing id 6390 to 1633
# reindexing id 6391 to 1634
# reindexing id 6392 to 1635
# reindexing id 6393 to 1636
# reindexing id 6394 to 1637
# reindexing id 6399 to 1638
# reindexing id 6400 to 1639
# reindexing id 6401 to 1640
# reindexing id 6402 to 1641
# reindexing id 6404 to 1642
# reindexing id 6405 to 1643
# reindexing id 6407 to 1644
# reindexing id 6408 to 1645
# reindexing id 6410 to 1646
# reindexing id 6412 to 1647
# reindexing id 6413 to 1648
# reindexing id 6414 to 1649
# reindexing id 6416 to 1650
# reindexing id 6417 to 1651
# reindexing id 6420 to 1652
# reindexing id 6421 to 1653
# reindexing id 6422 to 1654
# reindexing id 6423 to 1655
# reindexing id 6424 to 1656
# reindexing id 6425 to 1657
# reindexing id 6426 to 1658
# reindexing id 6427 to 1659
# reindexing id 6428 to 1660
# reindexing id 6429 to 1661
# reindexing id 6430 to 1662
# reindexing id 6431 to 1663
# reindexing id 6432 to 1664
# reindexing id 6433 to 1665
# reindexing id 6434 to 1666
# reindexing id 6438 to 1667
# reindexing id 6440 to 1668
# reindexing id 6441 to 1669
# reindexing id 6444 to 1670
# reindexing id 6445 to 1671
# reindexing id 6447 to 1672
# reindexing id 6448 to 1673
# reindexing id 6453 to 1674
# reindexing id 6454 to 1675
# reindexing id 6455 to 1676
# reindexing id 6457 to 1677
# reindexing id 6459 to 1678
# reindexing id 6460 to 1679
# reindexing id 6461 to 1680
# reindexing id 6465 to 1681
# reindexing id 6466 to 1682
# reindexing id 6468 to 1683
# reindexing id 6470 to 1684
# reindexing id 6474 to 1685
# reindexing id 6475 to 1686
# reindexing id 6476 to 1687
# reindexing id 6480 to 1688
# reindexing id 6487 to 1689
# reindexing id 6491 to 1690
# reindexing id 6492 to 1691
# reindexing id 6494 to 1692
# reindexing id 6495 to 1693
# reindexing id 6497 to 1694
# reindexing id 6500 to 1695
# reindexing id 6517 to 1696
# reindexing id 6518 to 1697
# reindexing id 6519 to 1698
# reindexing id 6523 to 1699
# reindexing id 6525 to 1700
# reindexing id 6526 to 1701
# reindexing id 6530 to 1702
# reindexing id 6532 to 1703
# reindexing id 6537 to 1704
# reindexing id 6539 to 1705
# reindexing id 6541 to 1706
# reindexing id 6553 to 1707
# reindexing id 6554 to 1708
# reindexing id 6555 to 1709
# reindexing id 6556 to 1710
# reindexing id 6560 to 1711
# reindexing id 6563 to 1712
# reindexing id 6565 to 1713
# reindexing id 6567 to 1714
# reindexing id 6568 to 1715
# reindexing id 6578 to 1716
# reindexing id 6581 to 1717
# reindexing id 6584 to 1718
# reindexing id 6587 to 1719
# reindexing id 6591 to 1720
# reindexing id 6595 to 1721
# reindexing id 6599 to 1722
# reindexing id 6600 to 1723
# reindexing id 6601 to 1724
# reindexing id 6602 to 1725
# reindexing id 6603 to 1726
# reindexing id 6604 to 1727
# reindexing id 6607 to 1728
# reindexing id 6612 to 1729
# reindexing id 6613 to 1730
# reindexing id 6614 to 1731
# reindexing id 6615 to 1732
# reindexing id 6619 to 1733
# reindexing id 6621 to 1734
# reindexing id 6623 to 1735
# reindexing id 6630 to 1736
# reindexing id 6713 to 1737
# reindexing id 6716 to 1738
# reindexing id 6718 to 1739
# reindexing id 6719 to 1740
# reindexing id 6772 to 1741
# reindexing id 6779 to 1742
# reindexing id 6780 to 1743
# reindexing id 6781 to 1744
# reindexing id 6782 to 1745
# reindexing id 6821 to 1746
# reindexing id 6822 to 1747
# reindexing id 6823 to 1748
# reindexing id 6824 to 1749
# reindexing id 6826 to 1750
# reindexing id 6827 to 1751
# reindexing id 6828 to 1752
# reindexing id 6829 to 1753
# reindexing id 6830 to 1754
# reindexing id 6831 to 1755
# reindexing id 6832 to 1756
# reindexing id 6833 to 1757
# reindexing id 6834 to 1758
# reindexing id 6835 to 1759
# reindexing id 6840 to 1760
# reindexing id 6841 to 1761
# reindexing id 6842 to 1762
# reindexing id 6847 to 1763
# reindexing id 6849 to 1764
# reindexing id 6850 to 1765
# reindexing id 6862 to 1766
# reindexing id 6864 to 1767
# reindexing id 6866 to 1768
# reindexing id 6867 to 1769
# reindexing id 6873 to 1770
# reindexing id 6875 to 1771
# reindexing id 6879 to 1772
# reindexing id 6885 to 1773
# reindexing id 6958 to 1774
# reindexing id 6966 to 1775
# reindexing id 6967 to 1776
# reindexing id 6968 to 1777
# reindexing id 6969 to 1778
# reindexing id 6971 to 1779
# reindexing id 6973 to 1780
# reindexing id 6975 to 1781
# reindexing id 6977 to 1782
# reindexing id 6979 to 1783
# reindexing id 6980 to 1784
# reindexing id 6981 to 1785
# reindexing id 6982 to 1786
# reindexing id 6983 to 1787
# reindexing id 6985 to 1788
# reindexing id 6987 to 1789
# reindexing id 6991 to 1790
# reindexing id 6995 to 1791
# reindexing id 6996 to 1792
# reindexing id 7012 to 1793
# reindexing id 7013 to 1794
# reindexing id 7016 to 1795
# reindexing id 7017 to 1796
# reindexing id 7018 to 1797
# reindexing id 7031 to 1798
# reindexing id 7032 to 1799
# reindexing id 7034 to 1800
# reindexing id 7035 to 1801
# reindexing id 7036 to 1802
# reindexing id 7039 to 1803
# reindexing id 7041 to 1804
# reindexing id 7042 to 1805
# reindexing id 7043 to 1806
# reindexing id 7044 to 1807
# reindexing id 7104 to 1808
# reindexing id 7118 to 1809
# reindexing id 7126 to 1810
# reindexing id 7132 to 1811
# reindexing id 7138 to 1812
# reindexing id 7141 to 1813
# reindexing id 7143 to 1814
# reindexing id 7144 to 1815
# reindexing id 7146 to 1816
# reindexing id 7149 to 1817
# reindexing id 7150 to 1818
# reindexing id 7151 to 1819
# reindexing id 7153 to 1820
# reindexing id 7154 to 1821
# reindexing id 7168 to 1822
# reindexing id 7175 to 1823
# reindexing id 7176 to 1824
# reindexing id 7179 to 1825
# reindexing id 7193 to 1826
# reindexing id 7227 to 1827
# reindexing id 7231 to 1828
# reindexing id 7232 to 1829
# reindexing id 7255 to 1830
# reindexing id 7286 to 1831
# reindexing id 7328 to 1832
# reindexing id 7331 to 1833
# reindexing id 7351 to 1834
# reindexing id 7353 to 1835
# reindexing id 7357 to 1836
# reindexing id 7358 to 1837
# reindexing id 7359 to 1838
# reindexing id 7361 to 1839
# reindexing id 7362 to 1840
# reindexing id 7371 to 1841

# %%
object_ids = object_ids.astype(np.uint8)
sobelx = cv2.Sobel(object_ids, cv2.CV_64F, 1, 0, ksize=3)
sobely = cv2.Sobel(object_ids, cv2.CV_64F, 0, 1, ksize=3)

# Gradient magnitude
magnitude = cv2.magnitude(sobelx, sobely)
magnitude = cv2.convertScaleAbs(magnitude)

_, edges = cv2.threshold(magnitude, 1, 255, cv2.THRESH_BINARY)
plt.imshow(edges)
plt.axis('off')
plt.show()

plt.imshow(rgb_img)
plt.imshow(edges, alpha=0.5)
plt.axis('off')
plt.show()

# Find contours
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# Draw contours on the original image
contour_img = rgb_img.copy()
for i, contour in enumerate(contours):
    # Draw each contour with a different color
    cv2.drawContours(contour_img, contours, i, (0, 255, 0), 2)
    
plt.imshow(contour_img)
plt.axis('off')
plt.show()

print(contours[0])
# Out:
# [[[1132  718]]
#
#  [[1132  719]]
#
#  [[1135  719]]
#
#  [[1135  718]]]

# %%
def find_shared_edges_and_ids(instance_mask):
    H, W = instance_mask.shape
    edge_map = np.zeros((H, W), dtype=np.uint8)
    edge_to_id_pair = {}

    # Pad to avoid boundary issues
    padded = np.pad(instance_mask, ((1,1), (1,1)), mode='constant', constant_values=0)

    # Directions: top, bottom, left, right
    neighbors = [(-1, 0), (1, 0), (0, -1), (0, 1)]

    for y in range(1, H+1):
        for x in range(1, W+1):
            center_id = padded[y, x]
            if center_id == 0:
                continue  # Skip background

            for dy, dx in neighbors:
                neighbor_id = padded[y+dy, x+dx]
                if neighbor_id != center_id and neighbor_id != 0:
                    # Inter-instance edge
                    edge_map[y-1, x-1] = 255
                    id_pair = tuple(sorted((center_id, neighbor_id)))  # (smaller, larger)
                    edge_to_id_pair[(y-1, x-1)] = id_pair
                    break  # Already found a neighbor with a different ID

    return edge_map, edge_to_id_pair

edge_map, edge_to_id_pair = find_shared_edges_and_ids(object_ids)
plt.imshow(edge_map)
plt.axis('off')
plt.savefig('/home/siddhartha/Downloads/contour_map.png', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
shared_contours = {}
for xy, id_pair in edge_to_id_pair.items():
    id = '_'.join([str(int(id)) for id in sorted(list(id_pair))])
    if id not in shared_contours:
        shared_contours[id] = []
    shared_contours[id].append(xy)
len(shared_contours.keys())
# Out:
# 3021

# %%
mean_depths = {}
def add_flying_pixels(pc_im, shared_contours, displacement_std=0.015):
    """Add flying pixels at depth discontinuities."""
    pc_img = pc_im.copy()
    # Add noise to edge points
    for key in shared_contours:
        obj1, obj2 = key.split('_')
        obj1 = int(obj1)
        obj2 = int(obj2)

        obj1_mean_depth = mean_depths.get(obj1, np.nanmean(pc_img[object_ids == obj1]))
        obj2_mean_depth = mean_depths.get(obj2, np.nanmean(pc_img[object_ids == obj2]))
        mean_depths[obj1] = obj1_mean_depth
        mean_depths[obj2] = obj2_mean_depth
        
        for pt_idx in shared_contours[key][::5]:
            if np.isnan(pc_img[pt_idx[0], pt_idx[1]]).any():
                continue
            neighborhood = pc_img[pt_idx[0]-2:pt_idx[0]+3, pt_idx[1]-2:pt_idx[1]+3, 2]
            bigger_neighborhood = pc_img[pt_idx[0]-5:pt_idx[0]+6, pt_idx[1]-5:pt_idx[1]+6, 2]
            # noise = np.random.normal(0,displacement_std, neighborhood.shape)
            depth_diff = abs(obj1_mean_depth - obj2_mean_depth)

            # noise = -1*abs(np.random.normal(0, displacement_std, neighborhood.shape))
            noise  = np.random.uniform(-depth_diff, 0, neighborhood.shape)


            normal_noise = -1*abs(np.random.normal(0, displacement_std, bigger_neighborhood.shape))

            # only noise the pixels of the front object
            if obj1_mean_depth < obj2_mean_depth:
                noise[neighborhood < obj1_mean_depth] = 0
                normal_noise[bigger_neighborhood < obj1_mean_depth] = 0
            else:
                noise[neighborhood > obj1_mean_depth] = 0
                normal_noise[bigger_neighborhood > obj1_mean_depth] = 0
            
            new_depths_1 = pc_img[pt_idx[0]-2:pt_idx[0]+3, pt_idx[1]-2:pt_idx[1]+3,2]+ noise
            # project each point to the new depth
            pc_img[pt_idx[0]-2:pt_idx[0]+3, pt_idx[1]-2:pt_idx[1]+3,:2]*= (new_depths_1 / pc_img[pt_idx[0]-2:pt_idx[0]+3, pt_idx[1]-2:pt_idx[1]+3,2])[:, :, np.newaxis]
            new_depths_2 = pc_img[pt_idx[0]-5:pt_idx[0]+6, pt_idx[1]-5:pt_idx[1]+6,2]+ normal_noise
            # project each point to the new depth
            pc_img[pt_idx[0]-5:pt_idx[0]+6, pt_idx[1]-5:pt_idx[1]+6,:2]*= (new_depths_2 / pc_img[pt_idx[0]-5:pt_idx[0]+6, pt_idx[1]-5:pt_idx[1]+6,2])[:, :, np.newaxis]
            pc_img[pt_idx[0]-2:pt_idx[0]+3, pt_idx[1]-2:pt_idx[1]+3,2]+= noise
            pc_img[pt_idx[0]-5:pt_idx[0]+6, pt_idx[1]-5:pt_idx[1]+6,2]+= normal_noise
    return pc_img


noised_pc_img = add_flying_pixels(pc_img, shared_contours)
pcd_noised = pc_img_to_pcd(noised_pc_img, rgb_img)
o3d.visualization.draw_geometries([pcd_noised])

# %%
plt.imshow(rgb_img)

# %%
def blur_img_edges(rgb_im, shared_contours, blur_radius=2):
    """Blur the edges of the image."""
    rgb_img = rgb_im.copy()
    for key in shared_contours:
        obj1, obj2 = key.split('_')
        obj1 = int(obj1)
        obj2 = int(obj2)

        for pt_idx in shared_contours[key][::5]:
            if np.isnan(rgb_img[pt_idx[0], pt_idx[1]]).any():
                continue
            # Get the region around the edge point
            x, y = pt_idx
            x_start = max(0, x - blur_radius)
            x_end = min(rgb_img.shape[0], x + blur_radius)
            y_start = max(0, y - blur_radius)
            y_end = min(rgb_img.shape[1], y + blur_radius)

            # Apply Gaussian blur to the region
            rgb_img[x_start:x_end, y_start:y_end] = cv2.GaussianBlur(rgb_img[x_start:x_end, y_start:y_end], (3, 3), 0)
    return rgb_img

blurred_rgb_img = blur_img_edges(rgb_img, shared_contours)

x1, y1, x2, y2 = 140.0, 430.0, 250.0, 340.0
# cv2.rectangle(blurred_rgb_img, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
# plt.imshow(blurred_rgb_img)
# plt.show()
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(blurred_rgb_img[int(y2):int(y1), int(x1):int(x2)])
ax[0].axis('off')
ax[1].imshow(rgb_img[int(y2):int(y1), int(x1):int(x2)])
ax[1].axis('off')
plt.show()

# show apple point cloud
crop_noise_pc_img = noised_pc_img[int(y2):int(y1), int(x1):int(x2)]
pcd_crop = pc_img_to_pcd(crop_noise_pc_img, blurred_rgb_img[int(y2):int(y1), int(x1):int(x2)])
o3d.visualization.draw_geometries([pcd_crop])

# %%
def add_distance_based_noise(pc_im, base_noise=0.004, meter_noise_percent=0.0025):
    pc_img = pc_im.copy()
    print(pc_img.shape)
    # add noise based on z val. higher z val, more noise
    ## ±4 mm + 0.25% of depth
    noise = np.random.normal(0, base_noise + meter_noise_percent * -1*pc_img[:, :, 2], pc_img[:,:,2].shape)
    new_depths = pc_img[:, :, 2] + noise
    # project each point to the new depth
    pc_img[:, :, :2] *= (new_depths / pc_img[:, :, 2])[:, :, np.newaxis]
    pc_img[:, :, 2] += noise
    return pc_img

noised_pc_img = add_distance_based_noise(noised_pc_img)
pcd_noised = pc_img_to_pcd(noised_pc_img, blurred_rgb_img)
o3d.visualization.draw_geometries([pcd_noised])
# Out:
# (720, 1280, 3)

# %%
def random_dropout(pc_img, rgb_img, dropout_rate=0.9):
    """Randomly drop points in the point cloud and associated RGB values."""
    pc_img = pc_img.copy()
    rgb_img = rgb_img.copy()
    mask = np.random.rand(*pc_img.shape[:2]) < dropout_rate
    pc_img[mask] = np.nan
    rgb_img[mask] = 0
    return pc_img, rgb_img

dropped_noised_pc_img, dropped_rgb = random_dropout(noised_pc_img, blurred_rgb_img, dropout_rate=0.75)
dropped_noised_pcd = pc_img_to_pcd(dropped_noised_pc_img, dropped_rgb)
o3d.visualization.draw_geometries([dropped_noised_pcd])

crop_noise_pc_img = dropped_noised_pc_img[int(y2):int(y1), int(x1):int(x2)]
pcd_crop = pc_img_to_pcd(crop_noise_pc_img, blurred_rgb_img[int(y2):int(y1), int(x1):int(x2)])
o3d.visualization.draw_geometries([pcd_crop])

print("Num points before", np.sum(~np.isnan(pc_img)))
print("Num points after", np.sum(~np.isnan(dropped_noised_pc_img)))
# Out:
# Num points before 2531436
# Num points after 631584

# %%
test_pc_path = '/media/siddhartha/sea/RIVAL_DATA/alacs_tof/10-21/2/20241021-152650_pc.npy'
test_pc_img = np.load(test_pc_path)
test_pc_3d = test_pc_img.reshape(-1,3)
test_pc_3d = test_pc_3d[~np.isnan(test_pc_3d).any(axis=1)]
print("Total valid points", sum(test_pc_3d[:,2] > 0))

test_rgb_path = '/media/siddhartha/sea/RIVAL_DATA/alacs_tof/10-21/2/20241021-152650_2284.90954_rgb.png'
test_rgb_img = cv2.imread(test_rgb_path)
test_rgb_img = cv2.cvtColor(test_rgb_img, cv2.COLOR_BGR2RGB)

pcd = pc_img_to_pcd(test_pc_img, test_rgb_img)
o3d.visualization.draw_geometries([pcd])
# Out:
# Total valid points 578062
